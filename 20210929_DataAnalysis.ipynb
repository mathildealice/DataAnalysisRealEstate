# %%
import pandas as pd

df = pd.read_csv('original_dataset.csv', low_memory = False, dtype = {'locality': str, 'postcode': str, 'property_subtype': str})

df.head()
# Out:
#    source hyperlink locality postcode  house_is    property_subtype   price  \
# 0       6   8901695     4180     4180      True  MIXED_USE_BUILDING  295000
# 1       6   8747010     8730     8730      True               VILLA  675000
# 2       6   8775843     4020     4020      True     APARTMENT_BLOCK  250000
# 3       6   8910441     1200     1200      True               HOUSE  545000
# 4       6   8758672     1190     1190      True  MIXED_USE_BUILDING  500000
#
#   sale rooms_number area  ... open_fire terrace terrace_area garden  \
# 0  NaN            3  242  ...     False    True           36   True
# 1  NaN            4  349  ...     False   False            0   True
# 2  NaN            5  303  ...     False   False            0  False
# 3  NaN            4  235  ...     False   False            0  False
# 4  NaN            2  220  ...     False   False            0   True
#
#   garden_area land_surface land_plot_surface facades_number swimming_pool_has  \
# 0        1000         1403              1403              0             False
# 1         977         1526              1526              0             False
# 2           0          760               760              0             False
# 3           0           63                63              0             False
# 4          60          193               193              0             False
#
#    building_state
# 0            GOOD
# 1          AS_NEW
# 2     TO_RENOVATE
# 3  JUST_RENOVATED
# 4          AS_NEW
#
# [5 rows x 22 columns]

# %%
counts = df.nunique()
counts
# Out:
# source                   6
# hyperlink            46721
# locality              5770
# postcode              1029
# house_is                 2
# property_subtype       205
# price                 7102
# sale                    19
# rooms_number            82
# area                  3368
# kitchen_has              2
# furnished                2
# open_fire                2
# terrace                  6
# terrace_area           185
# garden                 145
# garden_area            931
# land_surface          2853
# land_plot_surface     5890
# facades_number          13
# swimming_pool_has        5
# building_state          17
# dtype: int64

# %%
df['locality'] = pd.to_numeric(df['locality'], errors='coerce')
df['postcode'] = pd.to_numeric(df['postcode'], errors='coerce') 
df.dtypes
# Out:
# source                 int64
# hyperlink             object
# locality             float64
# postcode             float64
# house_is                bool
# property_subtype      object
# price                 object
# sale                  object
# rooms_number          object
# area                  object
# kitchen_has           object
# furnished             object
# open_fire             object
# terrace               object
# terrace_area          object
# garden                object
# garden_area           object
# land_surface          object
# land_plot_surface     object
# facades_number        object
# swimming_pool_has     object
# building_state        object
# dtype: object

# %%
df["locality"].fillna(df["postcode"], inplace=True)
df.loc[df['postcode']!=df['locality']]
# Out:
#        source                                          hyperlink  locality  \
# 18034       2  https://www.realo.be/en/rue-rimiere-105-4120-r...       NaN
# 18035       2  https://www.realo.be/en/sint-truidensesteenweg...       NaN
# 18036       2  https://www.realo.be/en/augustijnenlaan-77-220...       NaN
# 18037       2  https://www.realo.be/en/averbodesesteenweg-19-...       NaN
# 18038       2  https://www.realo.be/en/edward-pynaertkaai-21-...       NaN
# ...       ...                                                ...       ...
# 25441       2                                                NaN       NaN
# 25442       2                                                NaN       NaN
# 25443       2                                                NaN       NaN
# 25444       2                                                NaN       NaN
# 25445       2                                                NaN       NaN
#
#        postcode  house_is property_subtype            price        sale  \
# 18034       NaN      True            House                0         NaN
# 18035       NaN      True            House  340000€ 340.000         NaN
# 18036       NaN     False             Flat  259000€ 259.000         NaN
# 18037       NaN      True            House  449000€ 449.000         NaN
# 18038       NaN     False             Flat  249900€ 249.900         NaN
# ...         ...       ...              ...              ...         ...
# 25441       NaN     False        Apartment       1,195,000    Apartment
# 25442       NaN     False          Wohnung       1,195,000      Wohnung
# 25443       NaN     False        Apartment       1,195,000    Apartment
# 25444       NaN     False        Apartment       1,195,000    Apartment
# 25445       NaN     False     Loft / Attic       1,195,000    Apartment
#
#       rooms_number      area  ... open_fire terrace terrace_area garden  \
# 18034            0         0  ...     False   False          NaN  False
# 18035            3     170m2  ...     False   False          NaN   True
# 18036            2      88m2  ...      True   False          NaN   True
# 18037            4     303m2  ...      True   False          NaN   True
# 18038            3     102m2  ...      True   False          NaN   True
# ...            ...       ...  ...       ...     ...          ...    ...
# 25441            6  2,249.33  ...     False     NaN         None  False
# 25442            9   2690,98  ...     False     NaN         None  False
# 25443            3  1,453.13  ...     False     NaN         None  False
# 25444            5  1,388.54  ...     False     NaN         None  False
# 25445           10  1,905.21  ...     False     NaN         None   True
#
#       garden_area land_surface land_plot_surface facades_number  \
# 18034         NaN          NaN                No            NaN
# 18035         NaN          NaN               Yes            NaN
# 18036         NaN          NaN               Yes            NaN
# 18037         NaN          NaN               Yes            NaN
# 18038         NaN          NaN               Yes            NaN
# ...           ...          ...               ...            ...
# 25441           0         None         1,195,000           None
# 25442           0         None         1,195,000           None
# 25443           0         None         1,195,000           None
# 25444           0         None         1,195,000           None
# 25445           1         None         1,195,000           None
#
#       swimming_pool_has building_state
# 18034             False            NaN
# 18035             False            NaN
# 18036             False            NaN
# 18037             False            NaN
# 18038             False            NaN
# ...                 ...            ...
# 25441             False           None
# 25442             False           None
# 25443             False           None
# 25444              True           None
# 25445              True           None
#
# [7412 rows x 22 columns]

# %%
df.loc[(pd.isnull(df['postcode'])==False) & (df['locality'].isnull())]
df.loc[(pd.isnull(df['locality'])==False) & (df['postcode'].isnull())]
# Out:
# Empty DataFrame
# Columns: [source, hyperlink, locality, postcode, house_is, property_subtype, price, sale, rooms_number, area, kitchen_has, furnished, open_fire, terrace, terrace_area, garden, garden_area, land_surface, land_plot_surface, facades_number, swimming_pool_has, building_state]
# Index: []
#
# [0 rows x 22 columns]

# %%
df = df.loc[(pd.isnull(df['postcode'])==False) & (pd.isnull(df['locality'])==False)]
df
# Out:
#        source hyperlink  locality  postcode  house_is    property_subtype  \
# 0           6   8901695    4180.0    4180.0      True  MIXED_USE_BUILDING
# 1           6   8747010    8730.0    8730.0      True               VILLA
# 2           6   8775843    4020.0    4020.0      True     APARTMENT_BLOCK
# 3           6   8910441    1200.0    1200.0      True               HOUSE
# 4           6   8758672    1190.0    1190.0      True  MIXED_USE_BUILDING
# ...       ...       ...       ...       ...       ...                 ...
# 93063       3       NaN    2650.0    2650.0     False                 NaN
# 93064       3       NaN    3700.0    3700.0     False                 NaN
# 93065       3       NaN    3800.0    3800.0     False                 NaN
# 93066       3       NaN    2610.0    2610.0     False                 NaN
# 93067       3       NaN    9840.0    9840.0     False                 NaN
#
#          price sale rooms_number    area  ... open_fire terrace terrace_area  \
# 0       295000  NaN            3     242  ...     False    True           36
# 1       675000  NaN            4     349  ...     False   False            0
# 2       250000  NaN            5     303  ...     False   False            0
# 3       545000  NaN            4     235  ...     False   False            0
# 4       500000  NaN            2     220  ...     False   False            0
# ...        ...  ...          ...     ...  ...       ...     ...          ...
# 93063  210000€  NaN            2  100 m²  ...     False     NaN          NaN
# 93064  239000€  NaN            1   78 m²  ...     False     NaN          NaN
# 93065  259000€  NaN            2   90 m²  ...     False     NaN          NaN
# 93066  254000€  NaN            2   88 m²  ...     False     NaN          NaN
# 93067  359000€  NaN            2  140 m²  ...     False     NaN          NaN
#
#       garden garden_area land_surface land_plot_surface facades_number  \
# 0       True        1000         1403              1403              0
# 1       True         977         1526              1526              0
# 2      False           0          760               760              0
# 3      False           0           63                63              0
# 4       True          60          193               193              0
# ...      ...         ...          ...               ...            ...
# 93063  False         NaN          NaN               NaN              2
# 93064  False         NaN          NaN               NaN              4
# 93065  False         NaN          NaN               NaN              2
# 93066  False         NaN          NaN               NaN              2
# 93067  False         NaN          NaN               NaN              4
#
#       swimming_pool_has  building_state
# 0                 False            GOOD
# 1                 False          AS_NEW
# 2                 False     TO_RENOVATE
# 3                 False  JUST_RENOVATED
# 4                 False          AS_NEW
# ...                 ...             ...
# 93063                 0     To renovate
# 93064                 0            Good
# 93065                 0          As new
# 93066                 0   Not specified
# 93067                 0   Not specified
#
# [85656 rows x 22 columns]

# %%
subtype = df['property_subtype'].unique()
subtype
# Out:
# array(['MIXED_USE_BUILDING', 'VILLA', 'APARTMENT_BLOCK', 'HOUSE',
#        'EXCEPTIONAL_PROPERTY', 'MANSION', 'TOWN_HOUSE', 'COUNTRY_COTTAGE',
#        'MANOR_HOUSE', 'OTHER_PROPERTY', 'FARMHOUSE', 'CASTLE',
#        'APARTMENT', 'BUNGALOW', 'CHALET', 'PENTHOUSE', 'SERVICE_FLAT',
#        'LOFT', 'DUPLEX', 'FLAT_STUDIO', 'GROUND_FLOOR', 'TRIPLEX', 'KOT',
#        'house', 'mansion', 'villa', 'exceptional-property',
#        'apartment-block', 'town-house', 'apartment', 'penthouse',
#        'ground-floor', 'loft', 'flat-studio', 'duplex', 'triplex',
#        'mixed-use-building', 'farmhouse', 'bungalow', 'service-flat',
#        'country-cottage', 'other-property', 'kot', 'manor-house',
#        'chalet', 'castle', 'HOUSE_GROUP', 'APARTMENT_GROUP', 'House',
#        'Town-house', 'Apartment', nan], dtype=object)

# %%
counts = df.nunique()
counts
# Out:
# source                   5
# hyperlink            46264
# locality              1029
# postcode              1029
# house_is                 2
# property_subtype        51
# price                 5835
# sale                    11
# rooms_number            81
# area                  1746
# kitchen_has              2
# furnished                2
# open_fire                2
# terrace                  6
# terrace_area           185
# garden                 145
# garden_area            931
# land_surface          2853
# land_plot_surface     4565
# facades_number          13
# swimming_pool_has        5
# building_state          14
# dtype: int64

# %%
df['property_subtype']=df['property_subtype'].str.upper()
df['property_subtype'] = df['property_subtype'].str.replace('-','_')

# %%
counts = df.nunique()
counts
# Out:
# source                   5
# hyperlink            46264
# locality              1029
# postcode              1029
# house_is                 2
# property_subtype        25
# price                 5835
# sale                    11
# rooms_number            81
# area                  1746
# kitchen_has              2
# furnished                2
# open_fire                2
# terrace                  6
# terrace_area           185
# garden                 145
# garden_area            931
# land_surface          2853
# land_plot_surface     4565
# facades_number          13
# swimming_pool_has        5
# building_state          14
# dtype: int64

# %%
rooms_number = df['rooms_number'].unique()
rooms_number
# Out:
# array(['3', '4', '5', '2', '6', '7', '1', '8', '10', '41', '0', '11',
#        '15', '44', '9', '12', '14', '19', '13', '24', '18', '34', '17',
#        '16', '100', '49', '32', '71', '50', '20', '35', '99', '28', '25',
#        '30', '65', '22', '23', '21', '26', '36', '70', '46', '90', '80',
#        '40', '60', '204', 'None', nan, '6.0', '3.0', '5.0', '4.0', '2.0',
#        '7.0', '8.0', '1.0', '11.0', '10.0', '41.0', '12.0', '0.0', '9.0',
#        '15.0', '44.0', '13.0', '14.0', '18.0', '60.0', '20.0', '19.0',
#        '22.0', '24.0', '25.0', '34.0', '17.0', '16.0', '100.0', '165.0',
#        '49.0', 'Not specified'], dtype=object)

# %%
df['rooms_number'] = df['rooms_number'].str.replace('None','')
df['rooms_number'] = df['rooms_number'].str.replace('Not specified','')
df['rooms_number'] = df['rooms_number'].str.replace('nan','')

# %%
rooms_number = df['rooms_number'].unique()
rooms_number
# Out:
# array(['3', '4', '5', '2', '6', '7', '1', '8', '10', '41', '0', '11',
#        '15', '44', '9', '12', '14', '19', '13', '24', '18', '34', '17',
#        '16', '100', '49', '32', '71', '50', '20', '35', '99', '28', '25',
#        '30', '65', '22', '23', '21', '26', '36', '70', '46', '90', '80',
#        '40', '60', '204', '', nan, '6.0', '3.0', '5.0', '4.0', '2.0',
#        '7.0', '8.0', '1.0', '11.0', '10.0', '41.0', '12.0', '0.0', '9.0',
#        '15.0', '44.0', '13.0', '14.0', '18.0', '60.0', '20.0', '19.0',
#        '22.0', '24.0', '25.0', '34.0', '17.0', '16.0', '100.0', '165.0',
#        '49.0'], dtype=object)

# %%
df['rooms_number'] = pd.to_numeric(df['rooms_number'], errors='coerce').astype('Int64')

# %%
rooms_number = df['rooms_number'].unique()
rooms_number
# Out:
# <IntegerArray>
# [  3,   4,   5,   2,   6,   7,   1,   8,  10,  41,   0,  11,  15,  44,   9,
#   12,  14,  19,  13,  24,  18,  34,  17,  16, 100,  49,  32,  71,  50,  20,
#   35,  99,  28,  25,  30,  65,  22,  23,  21,  26,  36,  70,  46,  90,  80,
#   40,  60, 204, NaN, 165]
# Length: 50, dtype: Int64

# %%
terrace = df['terrace'].unique()
terrace
# Out:
# array(['True', 'False', nan, 'TRUE', '2.0', '3.0', '4.0'], dtype=object)

# %%
df.loc[(df['terrace']=='2.0')|(df['terrace']=='3.0')|(df['terrace']=='4.0')]
# Out:
#        source                                          hyperlink  locality  \
# 64895       1  https://www.immoweb.be/en/classified/house/for...    1180.0
# 65274       1  https://www.immoweb.be/en/classified/exception...    8000.0
# 65347       1  https://www.immoweb.be/en/classified/house/for...    1933.0
# 65535       1  https://www.immoweb.be/en/classified/house/for...    6240.0
# 65605       1  https://www.immoweb.be/en/classified/villa/for...    9840.0
# ...       ...                                                ...       ...
# 73422       1  https://www.immoweb.be/en/classified/house/for...    3770.0
# 74343       1  https://www.immoweb.be/en/classified/manor-hou...    8340.0
# 74488       1  https://www.immoweb.be/en/classified/mansion/f...    8000.0
# 74764       1  https://www.immoweb.be/en/classified/exception...    4987.0
# 75501       1  https://www.immoweb.be/en/classified/apartment...    1000.0
#
#        postcode  house_is      property_subtype       price              sale  \
# 64895    1180.0      True                 HOUSE   2950000.0  residential_sale
# 65274    8000.0      True  EXCEPTIONAL_PROPERTY   2399000.0  residential_sale
# 65347    1933.0      True                 HOUSE    549900.0  residential_sale
# 65535    6240.0      True                 HOUSE    250000.0  residential_sale
# 65605    9840.0      True                 VILLA    735000.0  residential_sale
# ...         ...       ...                   ...         ...               ...
# 73422    3770.0      True                 HOUSE    135000.0  residential_sale
# 74343    8340.0      True           MANOR_HOUSE   1595000.0  residential_sale
# 74488    8000.0      True               MANSION   1385000.0  residential_sale
# 74764    4987.0      True  EXCEPTIONAL_PROPERTY  12345678.0  residential_sale
# 75501    1000.0     False             APARTMENT   1150000.0  residential_sale
#
#        rooms_number   area  ... open_fire terrace terrace_area garden  \
# 64895             5  600.0  ...     False     2.0         TRUE   30.0
# 65274             5  400.0  ...     False     2.0         TRUE  100.0
# 65347             3  209.0  ...       NaN     2.0          NaN    NaN
# 65535             3  175.0  ...       NaN     2.0          NaN    NaN
# 65605             5  612.0  ...       NaN     2.0          NaN    NaN
# ...             ...    ...  ...       ...     ...          ...    ...
# 73422             3  134.0  ...     False     2.0          NaN    NaN
# 74343             7  497.0  ...     False     2.0          NaN    NaN
# 74488             5  405.0  ...     False     3.0          NaN    NaN
# 74764             5  300.0  ...       NaN     2.0         TRUE   80.0
# 75501             4  260.0  ...     False     2.0         TRUE   11.0
#
#       garden_area land_surface land_plot_surface facades_number  \
# 64895         NaN      20000.0           20000.0            4.0
# 65274         NaN        100.0             334.0            4.0
# 65347         NaN        150.0             380.0            4.0
# 65535         NaN          NaN            1074.0            3.0
# 65605         NaN          NaN            1371.0            4.0
# ...           ...          ...               ...            ...
# 73422         NaN          NaN             535.0            3.0
# 74343         NaN          NaN           60000.0            NaN
# 74488         NaN          NaN             307.0            NaN
# 74764         NaN       1800.0            1950.0            3.0
# 75501         NaN          NaN               NaN            2.0
#
#       swimming_pool_has building_state
# 64895               NaN         AS_NEW
# 65274             FALSE         AS_NEW
# 65347               NaN            NaN
# 65535               NaN            NaN
# 65605               NaN            NaN
# ...                 ...            ...
# 73422             FALSE            NaN
# 74343             FALSE         AS_NEW
# 74488              TRUE         AS_NEW
# 74764               NaN            NaN
# 75501               NaN         AS_NEW
#
# [61 rows x 22 columns]

# %%
df['terrace'] = df['terrace'].str.replace('TRUE','True')

# %%
import numpy as np
df.loc[df['terrace'] == '4.0','terrace'] = np.nan
df.loc[df['terrace'] == '3.0','terrace'] = np.nan
df.loc[df['terrace'] == '2.0','terrace'] = np.nan

# %%
terrace = df['open_fire'].unique()
terrace
# Out:
# array([False, True, nan], dtype=object)

# %%
df['terrace'].astype(str).replace({'(?i)True|TBC': True, '(?i)False|nan': False}, regex=True)
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 93063    False
# 93064    False
# 93065    False
# 93066    False
# 93067    False
# Name: terrace, Length: 85656, dtype: bool

# %%
counts = df.nunique()
counts
#does not count nan?
# Out:
# source                   5
# hyperlink            46264
# locality              1029
# postcode              1029
# house_is                 2
# property_subtype        25
# price                 5835
# sale                    11
# rooms_number            49
# area                  1746
# kitchen_has              2
# furnished                2
# open_fire                2
# terrace                  2
# terrace_area           185
# garden                 145
# garden_area            931
# land_surface          2853
# land_plot_surface     4565
# facades_number          13
# swimming_pool_has        5
# building_state          14
# dtype: int64

# %%
#converting to boolean makes me loose some data ?
#df['terrace'] = df['terrace'].astype('bool')
#df.dtypes

# %%
counts = df['terrace'].unique()
counts
# Out:
# array(['True', 'False', nan], dtype=object)

# %%
garden = df['garden'].unique()
garden
# Out:
# array(['True', 'False', '16.0', '36.0', nan, '3749.0', '15.0', '45.0',
#        '31.0', '40.0', '25.0', '20.0', '120.0', '30.0', '60.0', '19.0',
#        '7.0', '127.0', '28.0', '50.0', '23.0', '26.0', '6.0', '10.0',
#        '70.0', '4.0', '100.0', '64.0', '12.0', '17.0', '24.0', '22.0',
#        '94.0', '55.0', '21.0', '145.0', '47.0', '8.0', '5.0', '18.0',
#        '80.0', '170.0', '13.0', '38.0', '9.0', '150.0', '27.0', '66.0',
#        '125.0', '48.0', '85.0', '75.0', '37.0', '11.0', '35.0', '32.0',
#        '41.0', '114.0', '1.0', '14.0', '44.0', '74.0', '53.0', '161.0',
#        '300.0', '43.0', '29.0', '90.0', '142.0', '105.0', '61.0', '62.0',
#        '96.0', '108.0', '157.0', '2.0', '54.0', '34.0', '180.0', '3.0',
#        '450.0', '112.0', '280.0', '33.0', '200.0', '140.0', '65.0',
#        '196.0', '56.0', '42.0', '51.0', '111.0', '86.0', '77.0', '110.0',
#        '63.0', '39.0', '57.0', '88.0', '93.0', '141.0', '72.0', '68.0',
#        '400.0', '159.0', '76.0', '95.0', '46.0', '122.0', '52.0', '89.0',
#        '271.0', '160.0', '78.0', '59.0', '97.0', '124.0', '49.0', '188.0',
#        '81.0', '220.0', '350.0', '261.0', '123.0', '71.0', '250.0',
#        '246.0', '213.0', '115.0', '230.0', '91.0', '58.0', '138.0',
#        '708.0', '165.0', '144.0', '500.0', '83.0', '73.0', '67.0',
#        '101.0', '82.0', '130.0', '69.0', '175.0', '312.0'], dtype=object)

# %%
df.loc[(df['garden']!='True')&(df['garden']!='False')]
# Out:
#        source                                          hyperlink  locality  \
# 64873       1  https://www.immoweb.be/en/classified/house/for...    1150.0
# 64874       1  https://www.immoweb.be/en/classified/house/for...    4180.0
# 64875       1  https://www.immoweb.be/en/classified/new-real-...    7500.0
# 64876       1  https://www.immoweb.be/en/classified/house/for...    4480.0
# 64877       1  https://www.immoweb.be/en/classified/mixed-use...    4180.0
# ...       ...                                                ...       ...
# 75872       1  https://www.immoweb.be/en/classified/penthouse...    8310.0
# 75873       1  https://www.immoweb.be/en/classified/apartment...    4020.0
# 75874       1  https://www.immoweb.be/en/classified/apartment...    4500.0
# 75875       1  https://www.immoweb.be/en/classified/apartment...    4800.0
# 90080       3                                                NaN    8800.0
#
#        postcode  house_is    property_subtype     price  \
# 64873    1150.0      True               HOUSE  990000.0
# 64874    4180.0      True               HOUSE  195000.0
# 64875    7500.0      True         HOUSE_GROUP       NaN
# 64876    4480.0      True               HOUSE  245000.0
# 64877    4180.0      True  MIXED_USE_BUILDING  295000.0
# ...         ...       ...                 ...       ...
# 75872    8310.0     False           PENTHOUSE  649000.0
# 75873    4020.0     False           APARTMENT   25000.0
# 75874    4500.0     False           APARTMENT   99000.0
# 75875    4800.0     False           APARTMENT  109000.0
# 90080    8800.0      True                 NaN    60000€
#
#                          sale  rooms_number   area  ... open_fire terrace  \
# 64873        residential_sale             6  485.0  ...     False     NaN
# 64874        residential_sale             3  242.0  ...     False     NaN
# 64875              group_sale           NaN    NaN  ...     False     NaN
# 64876        residential_sale             5  142.0  ...     False     NaN
# 64877        residential_sale             3  242.0  ...     False     NaN
# ...                       ...           ...    ...  ...       ...     ...
# 75872        residential_sale             2   98.0  ...     False     NaN
# 75873  annuity_monthly_amount             3  142.0  ...       NaN     NaN
# 75874        residential_sale             3  210.0  ...       NaN     NaN
# 75875        residential_sale             1   70.0  ...       NaN     NaN
# 90080                     NaN           NaN   1 m²  ...       NaN     NaN
#
#       terrace_area  garden garden_area land_surface land_plot_surface  \
# 64873         TRUE    16.0         NaN          NaN             251.0
# 64874         TRUE    36.0         NaN        100.0             475.0
# 64875          NaN     NaN         NaN          NaN               NaN
# 64876         TRUE  3749.0         NaN        250.0             615.0
# 64877         TRUE    36.0         NaN       1000.0            1403.0
# ...            ...     ...         ...          ...               ...
# 75872         TRUE    28.0         NaN          NaN               NaN
# 75873         TRUE     4.0         NaN          NaN               NaN
# 75874          NaN     NaN         NaN          NaN               NaN
# 75875          NaN     NaN         NaN          NaN               NaN
# 90080          NaN     NaN         NaN          NaN               NaN
#
#       facades_number swimming_pool_has building_state
# 64873            2.0             FALSE         AS_NEW
# 64874            3.0             FALSE            NaN
# 64875            NaN               NaN            NaN
# 64876            4.0             FALSE            NaN
# 64877            3.0             FALSE            NaN
# ...              ...               ...            ...
# 75872            NaN             FALSE         AS_NEW
# 75873            NaN               NaN         AS_NEW
# 75874            NaN               NaN            NaN
# 75875            NaN               NaN            NaN
# 90080            NaN               NaN            NaN
#
# [11004 rows x 22 columns]

# %%
def converter(c): 
    if (c['garden']=='True')|(c['garden']=='False'): 
        return c['garden'] 
    elif (pd.isnull(c['garden'])==False): 
        return 'True'
    else: 
        return np.nan

df['hyp_garden'] = df.apply(converter, axis = 1)
df.head()
# Out:
#    source hyperlink  locality  postcode  house_is    property_subtype   price  \
# 0       6   8901695    4180.0    4180.0      True  MIXED_USE_BUILDING  295000
# 1       6   8747010    8730.0    8730.0      True               VILLA  675000
# 2       6   8775843    4020.0    4020.0      True     APARTMENT_BLOCK  250000
# 3       6   8910441    1200.0    1200.0      True               HOUSE  545000
# 4       6   8758672    1190.0    1190.0      True  MIXED_USE_BUILDING  500000
#
#   sale  rooms_number area  ... terrace terrace_area garden garden_area  \
# 0  NaN             3  242  ...    True           36   True        1000
# 1  NaN             4  349  ...   False            0   True         977
# 2  NaN             5  303  ...   False            0  False           0
# 3  NaN             4  235  ...   False            0  False           0
# 4  NaN             2  220  ...   False            0   True          60
#
#   land_surface land_plot_surface facades_number swimming_pool_has  \
# 0         1403              1403              0             False
# 1         1526              1526              0             False
# 2          760               760              0             False
# 3           63                63              0             False
# 4          193               193              0             False
#
#    building_state hyp_garden
# 0            GOOD       True
# 1          AS_NEW       True
# 2     TO_RENOVATE      False
# 3  JUST_RENOVATED      False
# 4          AS_NEW       True
#
# [5 rows x 23 columns]

# %%
def splitter(s): 
    if (s['garden']!='True')&(s['garden']!='False'): 
        return s['garden']
    elif (pd.isnull(s['garden'])==False): 
        return s['garden_area']
    else: 
        return np.nan
    
df['hyp_garden_area'] = df.apply(splitter, axis = 1)
df.head()
# Out:
#    source hyperlink  locality  postcode  house_is    property_subtype   price  \
# 0       6   8901695    4180.0    4180.0      True  MIXED_USE_BUILDING  295000
# 1       6   8747010    8730.0    8730.0      True               VILLA  675000
# 2       6   8775843    4020.0    4020.0      True     APARTMENT_BLOCK  250000
# 3       6   8910441    1200.0    1200.0      True               HOUSE  545000
# 4       6   8758672    1190.0    1190.0      True  MIXED_USE_BUILDING  500000
#
#   sale  rooms_number area  ... terrace_area garden garden_area land_surface  \
# 0  NaN             3  242  ...           36   True        1000         1403
# 1  NaN             4  349  ...            0   True         977         1526
# 2  NaN             5  303  ...            0  False           0          760
# 3  NaN             4  235  ...            0  False           0           63
# 4  NaN             2  220  ...            0   True          60          193
#
#   land_plot_surface facades_number swimming_pool_has  building_state  \
# 0              1403              0             False            GOOD
# 1              1526              0             False          AS_NEW
# 2               760              0             False     TO_RENOVATE
# 3                63              0             False  JUST_RENOVATED
# 4               193              0             False          AS_NEW
#
#   hyp_garden hyp_garden_area
# 0       True            1000
# 1       True             977
# 2      False               0
# 3      False               0
# 4       True              60
#
# [5 rows x 24 columns]

# %%
garden = df['hyp_garden'].unique()
garden
# Out:
# array(['True', 'False', nan], dtype=object)

# %%
df.dtypes
# Out:
# source                 int64
# hyperlink             object
# locality             float64
# postcode             float64
# house_is                bool
# property_subtype      object
# price                 object
# sale                  object
# rooms_number           Int64
# area                  object
# kitchen_has           object
# furnished             object
# open_fire             object
# terrace               object
# terrace_area          object
# garden                object
# garden_area           object
# land_surface          object
# land_plot_surface     object
# facades_number        object
# swimming_pool_has     object
# building_state        object
# hyp_garden            object
# hyp_garden_area       object
# dtype: object

# %%
garden_area = df['hyp_garden_area'].unique()
garden_area
# Out:
# array(['1000', '977', '0', ..., '223', '1750', '116'], dtype=object)

# %%
df['hyp_garden_area'] = pd.to_numeric(df['hyp_garden_area'], errors='coerce').astype('Int64')

# %%
df.dtypes
# Out:
# source                 int64
# hyperlink             object
# locality             float64
# postcode             float64
# house_is                bool
# property_subtype      object
# price                 object
# sale                  object
# rooms_number           Int64
# area                  object
# kitchen_has           object
# furnished             object
# open_fire             object
# terrace               object
# terrace_area          object
# garden                object
# garden_area           object
# land_surface          object
# land_plot_surface     object
# facades_number        object
# swimming_pool_has     object
# building_state        object
# hyp_garden            object
# hyp_garden_area        Int64
# dtype: object

# %%
facades_number = df['facades_number'].unique()
facades_number
# Out:
# array(['0', '3', '2', '4', 'None', '1', '6', nan, '10', '2.0', '3.0',
#        '4.0', '1.0', '10.0'], dtype=object)

# %%
df.loc[df['facades_number']=='None', 'facades_number'] = np.nan

# %%
facades_number = df['facades_number'].unique()
facades_number
# Out:
# array(['0', '3', '2', '4', nan, '1', '6', '10', '2.0', '3.0', '4.0',
#        '1.0', '10.0'], dtype=object)

# %%
df['facades_number'] = pd.to_numeric(df['facades_number'], errors='coerce').astype('Int64')

# %%
facades_number = df['facades_number'].unique()
facades_number
# Out:
# <IntegerArray>
# [0, 3, 2, 4, NaN, 1, 6, 10]
# Length: 8, dtype: Int64

# %%
swimming_pool_has = df['swimming_pool_has'].unique()
swimming_pool_has
# Out:
# array(['False', 'True', 'FALSE', nan, 'TRUE', '0'], dtype=object)

# %%
df['swimming_pool_has'] = df['swimming_pool_has'].str.replace('TRUE','True')
df['swimming_pool_has'] = df['swimming_pool_has'].str.replace('FALSE','False')
df['swimming_pool_has'] = df['swimming_pool_has'].str.replace('0','False')

# %%
swimming_pool_has = df['swimming_pool_has'].unique()
swimming_pool_has
# Out:
# array(['False', 'True', nan], dtype=object)

# %%
df['swimming_pool_has'] = df['swimming_pool_has'].astype('bool')
df.dtypes
# Out:
# source                 int64
# hyperlink             object
# locality             float64
# postcode             float64
# house_is                bool
# property_subtype      object
# price                 object
# sale                  object
# rooms_number           Int64
# area                  object
# kitchen_has           object
# furnished             object
# open_fire             object
# terrace               object
# terrace_area          object
# garden                object
# garden_area           object
# land_surface          object
# land_plot_surface     object
# facades_number         Int64
# swimming_pool_has       bool
# building_state        object
# hyp_garden            object
# hyp_garden_area        Int64
# dtype: object

# %%
building_state = df['building_state'].unique()
building_state
# Out:
# array(['GOOD', 'AS_NEW', 'TO_RENOVATE', 'JUST_RENOVATED', 'TO_BE_DONE_UP',
#        'TO_RESTORE', nan, 'Not specified', '0', 'Good', 'To renovate',
#        'To be done up', 'As new', 'Just renovated', 'To restore'],
#       dtype=object)

# %%
df['building_state'] = df['building_state'].str.replace(' ','_')
df['building_state'] = df['building_state'].str.upper()
df['building_state'] = df['building_state'].str.replace('TO_RESTORE','TO_RENOVATE')
df['building_state'] = df['building_state'].str.replace('TO_BE_DONE_UP','TO_RENOVATE')
df['building_state'] = df['building_state'].str.replace('JUST_RENOVATED','AS_NEW')

# %%
building_state = df['building_state'].unique()
building_state
# Out:
# array(['GOOD', 'AS_NEW', 'TO_RENOVATE', nan, 'NOT_SPECIFIED', '0'],
#       dtype=object)

# %%
df.loc[df['building_state'] == 'NOT_SPECIFIED','building_state'] = np.nan
df.loc[df['building_state'] == '0','building_state'] = np.nan

# %%
building_state = df['building_state'].unique()
building_state
# Out:
# array(['GOOD', 'AS_NEW', 'TO_RENOVATE', nan], dtype=object)

# %%
counts = df.nunique()
counts
# Out:
# source                   5
# hyperlink            46264
# locality              1029
# postcode              1029
# house_is                 2
# property_subtype        25
# price                 5835
# sale                    11
# rooms_number            49
# area                  1746
# kitchen_has              2
# furnished                2
# open_fire                2
# terrace                  2
# terrace_area           185
# garden                 145
# garden_area            931
# land_surface          2853
# land_plot_surface     4565
# facades_number           7
# swimming_pool_has        1
# building_state           3
# hyp_garden               2
# hyp_garden_area        935
# dtype: int64

# %%
# Out:
# array([ True, False])
