# %% [markdown]
# # Notes préliminaires
# ### README
# Le fichier commence par la cell d'import des données.
# Une fois la première cellule lancée, il faut lire le fichier de bas en haut.
# Chaque cellule correspond à un "essai". Le but est en général décrit en commentaire.
# ## Questions
# ###### Is regex usage a recommanded way to go about data cleaning?

# %%
import pandas as pd
df = pd.read_csv('original_dataset.csv', low_memory = False, dtype = {'locality': str, 'postcode': str, 'property_subtype': str})

# %%
test_df = df 

#https://stackoverflow.com/questions/25292838/applying-regex-to-a-pandas-dataframe  
import re
def split_it(locality):
    return re.findall('(\d\d\d\d)', locality)
test_df['locality'].apply(split_it)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-0145835e45a0> in <module>
#       5 def split_it(locality):
#       6     return re.findall('(\d\d\d\d)', locality)
# ----> 7 test_df['locality'].apply(split_it)
#
# ~\Anaconda2\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4036             else:
#    4037                 values = self.astype(object).values
# -> 4038                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4039
#    4040         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-87-0145835e45a0> in split_it(locality)
#       4 import re
#       5 def split_it(locality):
# ----> 6     return re.findall('(\d\d\d\d)', locality)
#       7 test_df['locality'].apply(split_it)
#
# ...

# %%
test_df = df 
for row in df['locality']: 
    print(type(row))
    break;
# I have all string values so WHY IS IT NOT WORKING?
# Out:
# <class 'str'>

# %%
test_df = df
for row in df['locality']: 
    if row.str.contains('\d{4}', regex = True, na = False): 
        print(row)
#Pourquoi pour la colonne entière je peux appliquer mon 'str' et pas pour l'item ?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-047e42669e6c> in <module>
#       1 test_df = df
#       2 for row in df['locality']:
# ----> 3     if row.str.contains('\d{4}', regex = True, na = False):
#       4         print(row)
#
# AttributeError: 'str' object has no attribute 'str'

# %%
test_df = df 
for row in df['locality']: 
    if row == "1090": 
        print(row)
#ok to loop on all items, now I want to include regex.
# Out:
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# 1090
# ...

# %%
test_df = df
test_df['locality'][2]
#hypothese: il bug car il ne sait pas de quelle row on parle
# Out:
# '4020'

# %%
test_df = df
param = True
if param == True: 
    test_df['my_locality'] = test_df['locality']
else: 
    test_df['my_locality'] = np.nan
test_df.head()
#this condition seems to work fine
# Out:
#    source hyperlink locality postcode  house_is    property_subtype   price  \
# 0       6   8901695     4180     4180      True  MIXED_USE_BUILDING  295000
# 1       6   8747010     8730     8730      True               VILLA  675000
# 2       6   8775843     4020     4020      True     APARTMENT_BLOCK  250000
# 3       6   8910441     1200     1200      True               HOUSE  545000
# 4       6   8758672     1190     1190      True  MIXED_USE_BUILDING  500000
#
#   sale rooms_number area  ... terrace_area garden garden_area land_surface  \
# 0  NaN            3  242  ...           36   True        1000         1403
# 1  NaN            4  349  ...            0   True         977         1526
# 2  NaN            5  303  ...            0  False           0          760
# 3  NaN            4  235  ...            0  False           0           63
# 4  NaN            2  220  ...            0   True          60          193
#
# ...

# %%
test_df = df
import numpy as np
if np.logical_or(test_df['locality'].str.contains('\d{4}', regex = True, na = False), test_df['locality'].str.contains('\d{4}', regex = True, na = False)): 
    test_df['my_locality'] = test_df['locality']
else: 
    test_df['my_locality'] = np.nan
#using np.logical_or is not helpful
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-ef6059c16529> in <module>
#       1 test_df = df
#       2 import numpy as np
# ----> 3 if np.logical_or(test_df['locality'].str.contains('\d{4}', regex = True, na = False), test_df['locality'].str.contains('\d{4}', regex = True, na = False)):
#       4     test_df['my_locality'] = test_df['locality']
#       5 else:
#
# ~\Anaconda2\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1554             "The truth value of a {0} is ambiguous. "
#    1555             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1556                 self.__class__.__name__
#    1557             )
#    1558         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
test_df = df
test_df['locality'].str.contains('\d{4}', regex = True, na = False)
#I can conclude that the condition works when it stands alone 
#Why the ambiguity when used in if/else?
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 93063    True
# 93064    True
# 93065    True
# 93066    True
# 93067    True
# Name: locality, Length: 93068, dtype: bool

# %%
#Replacing boolean result by a chain defined by me.
test_df = df
if test_df['locality'].str.contains('\d{4}', regex = True, na = False): 
    test_df['my_col'] = "true condition" 
else: 
    test_df['my_col'] = "false condition"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-0f258b3a2adc> in <module>
#       1 test_df = df
# ----> 2 if test_df['locality'].str.contains('\d{4}', regex = True, na = False):
#       3     test_df['my_col'] = "true condition"
#       4 else:
#       5     test_df['my_col'] = "false condition"
#
# ~\Anaconda2\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1554             "The truth value of a {0} is ambiguous. "
#    1555             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1556                 self.__class__.__name__
#    1557             )
#    1558         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#works but...
test_df = df
test_df['my_col'] = test_df['locality'].str.contains('\d{4}', regex = True, na = False)
test_df.head()
# Out:
#    source hyperlink locality postcode  house_is    property_subtype   price  \
# 0       6   8901695     4180     4180      True  MIXED_USE_BUILDING  295000
# 1       6   8747010     8730     8730      True               VILLA  675000
# 2       6   8775843     4020     4020      True     APARTMENT_BLOCK  250000
# 3       6   8910441     1200     1200      True               HOUSE  545000
# 4       6   8758672     1190     1190      True  MIXED_USE_BUILDING  500000
#
#   sale rooms_number area  ... terrace terrace_area garden garden_area  \
# 0  NaN            3  242  ...    True           36   True        1000
# 1  NaN            4  349  ...   False            0   True         977
# 2  NaN            5  303  ...   False            0  False           0
# 3  NaN            4  235  ...   False            0  False           0
# 4  NaN            2  220  ...   False            0   True          60
#
#   land_surface land_plot_surface facades_number swimming_pool_has  \
# ...

# %%
#Still with the intent of generalizing the code, I will retry and also use a param "column_to_change"
test_df = df 
column_to_change = df['locality']
for col in column_to_change:
    test_df['my_col'] = test_df[col].str.contains('\d{4}', regex = True, na = False)
test_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-6223bef61fc9> in <module>
#       3 column_to_change = df['locality']
#       4 for col in column_to_change:
# ----> 5     test_df['my_col'] = col.str.contains('\d{4}', regex = True, na = False)
#       6 test_df.head()
#
# AttributeError: 'str' object has no attribute 'str'

# %%
#Trying a simple case of loop on columns
for locality in df['locality']: 
    if item.str.contains('\d{4}', regex = True, na = False): 
        print("contains 4 digits")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-cd37dc31bcdc> in <module>
#       1 #Trying a simple case of loop on columns
#       2 for locality in df['locality']:
# ----> 3     if item.str.contains('\d{4}', regex = True, na = False):
#       4         print("test")
#
# AttributeError: 'str' object has no attribute 'str'

# %%
# Trying to work with a column 
test_df = df
my_regex_dict = {'REGEX': '\d{4}', 'REGEX': '^(?!.{51,})(\w+ ?)$'}
import numpy as np
for key in my_regex_dict: 
    my_filter = test_df['locality'].str.contains(my_regex_dict[key], regex = True, na = False)
    if my_filter:
        return test_df['my_locality'] = test_df['locality']
    else: 
        return np.nan   
test_df.head()
#Problem : I gotta loop over the values of the column now
# Out:
#   File "<ipython-input-50-3120f25ed497>", line 8
#     return test_df['my_locality'] = test_df['locality']
#                                   ^
# SyntaxError: invalid syntax

# %%
# First step to refactoring with dictionnary
test_df = df
my_regex_dict = {'REGEX': '\d{4}', 'REGEX': '^(?!.{51,})(\w+ ?)$'}
for key in my_regex_dict: 
    print(key, '->', my_regex_dict[key])
#Printing only the last item
for key in my_regex_dict: 
    my_filter = test_df['locality'].str.contains(my_regex_dict[key], regex = True, na = False)
    test_df = test_df[~my_filter]
test_df.head()
#Currently I am extracting rows
#My actual goal is to clean and push to a clean column e.g. my_locality
# Out:
# REGEX -> ^(?!.{51,})(\w+ ?)$
#        source                                          hyperlink  \
# 18034       2  https://www.realo.be/en/rue-rimiere-105-4120-r...
# 18035       2  https://www.realo.be/en/sint-truidensesteenweg...
# 18036       2  https://www.realo.be/en/augustijnenlaan-77-220...
# 18037       2  https://www.realo.be/en/averbodesesteenweg-19-...
# 18038       2  https://www.realo.be/en/edward-pynaertkaai-21-...
#
#                                                 locality postcode  house_is  \
# 18034      Rue Rimière 105, 4120 Rotheux-Rimière, Neupré      NaN      True
# 18035  Sint-Truidensesteenweg 95A A, 3350 Orsmaal-Gus...      NaN      True
# 18036             Augustijnenlaan 77 201, 2200 Herentals      NaN     False
# 18037                Averbodesesteenweg 19, 2230 Herselt      NaN      True
# 18038               Edward pynaertkaai 21, 9050 Ledeberg      NaN     False
#
#       property_subtype            price sale rooms_number   area  ...  \
# ...

# %%
#Trying to filter out the clean part, where the postcode's locality is written and not something else
my_filter = df["locality"].str.contains('\d{4}', regex=True, na=False)
to_clean = df[~my_filter]
my_filter_2 = to_clean['locality'].str.contains('^(?!.{51,})(\w+ ?)$', regex=True, na=False)
to_clean = to_clean[my_filter_2]
to_clean.head()
#Mon filtre marche
#Next step working with a 'trash dict'
#contains regex or values that I consider unusable 
#for a regex, I need to set the regex param to True
# Out:
#        source                                          hyperlink locality  \
# 18461       2  https://www.realo.be/en/urbanizacion-torremar-...  Belgium
# 18492       2  https://www.realo.be/en/urbanizacion-torremar-...  Belgium
# 18540       2  https://www.realo.be/en/urbanizacion-torremar-...  Belgium
# 18588       2  https://www.realo.be/en/urbanizacion-torremar-...  Belgium
# 18656       2  https://www.realo.be/en/urbanizacion-torremar-...  Belgium
#
#       postcode  house_is property_subtype price sale rooms_number   area  ...  \
# 18461      NaN      True            House     0  NaN            3  150m2  ...
# 18492      NaN      True            House     0  NaN            3  150m2  ...
# 18540      NaN      True            House     0  NaN            3  150m2  ...
# 18588      NaN      True            House     0  NaN            3  150m2  ...
# 18656      NaN      True            House     0  NaN            3  150m2  ...
#
# ...

# %%
#Trying to identify weird cases of locality
my_filter = df["locality"].str.contains('\d{4}', regex=True, na=False)
df[~my_filter]
# Out:
#        source                                          hyperlink  \
# 18039       2  https://www.realo.be/en/engelstraat-148-9040-s...
# 18084       2  https://www.realo.be/en/pylyserlaan-59-8670-ko...
# 18092       2  https://www.realo.be/en/hippoliet-van-peenestr...
# 18097       2  https://www.realo.be/en/kortrijksesteenweg-170...
# 18098       2  https://www.realo.be/en/langemunt-52-9850-neve...
# ...       ...                                                ...
# 75871       1  https://www.immoweb.be/en/classified/penthouse...
# 75872       1  https://www.immoweb.be/en/classified/penthouse...
# 75873       1  https://www.immoweb.be/en/classified/apartment...
# 75874       1  https://www.immoweb.be/en/classified/apartment...
# 75875       1  https://www.immoweb.be/en/classified/apartment...
#
#                                                 locality postcode  house_is  \
# 18039            Zéér RUIME Bel-etage woning met ATELIER      NaN      True
# ...

# %%
#Trying to use regex filtering - V5
#No conversion to numeric value
my_filter = df["locality"].str.contains('\d{4}', regex=True, na=False)
df[my_filter]
# Out:
#        source hyperlink locality postcode  house_is    property_subtype  \
# 0           6   8901695     4180     4180      True  MIXED_USE_BUILDING
# 1           6   8747010     8730     8730      True               VILLA
# 2           6   8775843     4020     4020      True     APARTMENT_BLOCK
# 3           6   8910441     1200     1200      True               HOUSE
# 4           6   8758672     1190     1190      True  MIXED_USE_BUILDING
# ...       ...       ...      ...      ...       ...                 ...
# 93063       3       NaN     2650     2650     False                 NaN
# 93064       3       NaN     3700     3700     False                 NaN
# 93065       3       NaN     3800     3800     False                 NaN
# 93066       3       NaN     2610     2610     False                 NaN
# 93067       3       NaN     9840     9840     False                 NaN
#
#          price sale rooms_number    area  ... open_fire terrace terrace_area  \
# ...

# %%
#https://stackoverflow.com/questions/37080612/pandas-dataframe-filter-regex

import pandas as pd

df = pd.DataFrame(
    [
        ['Hello', 'World'],
        ['Just', 'Wanted'],
        ['To', 'Say'],
        ['I\'m', 'Tired']
    ]
)

df.filter([0], regex=r'(Hel|Just)', axis=0)

#it is supposed to work as I took the full example from internet, but does not work properly
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-a76ef7e41c5d> in <module>
#      10 )
#      11
# ---> 12 df.filter([0], regex=r'(Hel|Just)', axis=0)
#
# ~\Anaconda2\lib\site-packages\pandas\core\generic.py in filter(self, items, like, regex, axis)
#    4648         if nkw > 1:
#    4649             raise TypeError(
# -> 4650                 "Keyword arguments `items`, `like`, or `regex` "
#    4651                 "are mutually exclusive"
#    4652             )
#
# TypeError: Keyword arguments `items`, `like`, or `regex` are mutually exclusive

# %%
#Trying to use regex filtering - V3
#Trying the same on a string value
df.filter(['price'], regex=r'\d{4}', axis=0)
# What is the meaning of the error ?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-6975d1138982> in <module>
#       1 #Trying to use regex filtering - V3
# ----> 2 df.filter(['price'], regex=r'\d{4}', axis=0)
#
# ~\Anaconda2\lib\site-packages\pandas\core\generic.py in filter(self, items, like, regex, axis)
#    4648         if nkw > 1:
#    4649             raise TypeError(
# -> 4650                 "Keyword arguments `items`, `like`, or `regex` "
#    4651                 "are mutually exclusive"
#    4652             )
#
# TypeError: Keyword arguments `items`, `like`, or `regex` are mutually exclusive

# %%
#Trying to use regex filtering - V2
df['locality'] = pd.to_numeric(df['locality'], errors='coerce')
df['postcode'] = pd.to_numeric(df['postcode'], errors='coerce') 
#After converting to numeric, I cannot use contains anymore, is there an alternative ?
df.filter(['locality'], regex=r'\d{4}', axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2cb04977665f> in <module>
#       3 df['postcode'] = pd.to_numeric(df['postcode'], errors='coerce')
#       4 #After converting to numeric, I cannot use contains anymore
# ----> 5 df.filter(['locality'], regex=r'\d{4}', axis=0)
#
# ~\Anaconda2\lib\site-packages\pandas\core\generic.py in filter(self, items, like, regex, axis)
#    4648         if nkw > 1:
#    4649             raise TypeError(
# -> 4650                 "Keyword arguments `items`, `like`, or `regex` "
#    4651                 "are mutually exclusive"
#    4652             )
#
# TypeError: Keyword arguments `items`, `like`, or `regex` are mutually exclusive

# %%
#Trying to use regex filtering - V1
df['locality'] = pd.to_numeric(df['locality'], errors='coerce')
df['postcode'] = pd.to_numeric(df['postcode'], errors='coerce') 
#After converting to numeric, I cannot use contains anymore
my_filter = df["locality"].str.contains('\d{6}', regex=True, na=False)
df[my_filter]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-16063014a7b8> in <module>
# ----> 1 my_filter = df["locality"].str.contains('\d{6}', regex=True, na=False)
#       2 df[my_filter]
#       3 #df[~my_filter]
#       4 #same results
#
# ~\Anaconda2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5174             or name in self._accessors
#    5175         ):
# -> 5176             return object.__getattribute__(self, name)
#    5177         else:
#    5178             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda2\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
# ...
